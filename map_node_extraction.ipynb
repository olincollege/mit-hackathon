# %%
import matplotlib.pyplot as plt
import keras_ocr
pipeline = keras_ocr.pipeline.Pipeline()
image_path = "stata.jpeg"
#read image from the an image path (a jpg/png file or an image url)
img = keras_ocr.tools.read(image_path)
# Prediction_groups is a list of (word, box) tuples
prediction_groups = pipeline.recognize([img])
#print image with annotation and boxes
keras_ocr.tools.drawAnnotations(image=img, predictions=prediction_groups[0])
# Out:
# Looking for /Users/sallylee/.keras-ocr/craft_mlt_25k.h5
# Looking for /Users/sallylee/.keras-ocr/crnn_kurapan.h5
# 1/1 [==============================] - 9s 9s/step
# 2/2 [==============================] - 3s 91ms/step
# <Axes: >

# %%
prediction_groups
# Out:
# [[('d416',
#    array([[504.1162 ,  74.07422],
#           [621.4004 ,  74.07422],
#           [621.4004 , 119.3418 ],
#           [504.1162 , 119.3418 ]], dtype=float32)),
#   ('d414',
#    array([[397.12012, 150.20605],
#           [514.4043 , 150.20605],
#           [514.4043 , 191.3584 ],
#           [397.12012, 191.3584 ]], dtype=float32)),
#   ('d424',
#    array([[670.7832 , 232.51074],
#           [786.00977, 232.51074],
#           [786.00977, 275.7207 ],
#           [670.7832 , 275.7207 ]], dtype=float32)),
#   ('d428',
#    array([[878.60254, 232.51074],
#           [993.8291 , 232.51074],
#           [993.8291 , 275.7207 ],
#           [878.60254, 275.7207 ]], dtype=float32)),
#   ('da32',
#    array([[1065.8457 ,  234.56836],
#           [1179.0146 ,  234.56836],
#           [1179.0146 ,  275.7207 ],
#           [1065.8457 ,  275.7207 ]], dtype=float32)),
#   ('d412',
#    array([[351.85254, 257.20215],
#           [467.0791 , 257.20215],
#           [467.0791 , 300.4121 ],
#           [351.85254, 300.4121 ]], dtype=float32)),
#   ('da30',
#    array([[ 969.1377 ,  279.83594],
#           [1086.4219 ,  279.83594],
#           [1086.4219 ,  327.16113],
#           [ 969.1377 ,  327.16113]], dtype=float32)),
#   ('d426',
#    array([[763.376  , 281.89355],
#           [876.5449 , 281.89355],
#           [876.5449 , 325.10352],
#           [763.376  , 325.10352]], dtype=float32)),
#   ('d434',
#    array([[1183.1299 ,  281.89355],
#           [1300.4141 ,  281.89355],
#           [1300.4141 ,  325.10352],
#           [1183.1299 ,  325.10352]], dtype=float32)),
#   ('d410',
#    array([[207.81934, 353.91016],
#           [325.10352, 353.91016],
#           [325.10352, 399.17773],
#           [207.81934, 399.17773]], dtype=float32)),
#   ('d433',
#    array([[878.60254, 460.90625],
#           [993.8291 , 460.90625],
#           [993.8291 , 504.1162 ],
#           [878.60254, 504.1162 ]], dtype=float32)),
#   ('d406',
#    array([[327.16113, 462.96387],
#           [442.3877 , 462.96387],
#           [442.3877 , 504.1162 ],
#           [327.16113, 504.1162 ]], dtype=float32)),
#   ('d407',
#    array([[469.13672, 485.59766],
#           [584.3633 , 485.59766],
#           [584.3633 , 528.8076 ],
#           [469.13672, 528.8076 ]], dtype=float32)),
#   ('da29',
#    array([[712.208  , 573.46484],
#           [823.8669 , 576.2563 ],
#           [822.813  , 618.4111 ],
#           [711.15405, 615.6196 ]], dtype=float32)),
#   ('da33a',
#    array([[ 987.65625,  574.0752 ],
#           [1137.8623 ,  574.0752 ],
#           [1137.8623 ,  615.22754],
#           [ 987.65625,  615.22754]], dtype=float32)),
#   ('d450',
#    array([[668.7256 , 726.33887],
#           [783.95215, 726.33887],
#           [783.95215, 767.4912 ],
#           [668.7256 , 767.4912 ]], dtype=float32)),
#   ('d440',
#    array([[ 969.1377 ,  788.0674 ],
#           [1084.3643 ,  788.0674 ],
#           [1084.3643 ,  833.33496],
#           [ 969.1377 ,  833.33496]], dtype=float32)),
#   ('d451',
#    array([[730.4541, 948.5615],
#           [841.5654, 948.5615],
#           [841.5654, 991.7715],
#           [730.4541, 991.7715]], dtype=float32)),
#   ('d458',
#    array([[ 504.1162, 1098.7676],
#           [ 619.3428, 1098.7676],
#           [ 619.3428, 1141.9775],
#           [ 504.1162, 1141.9775]], dtype=float32)),
#   ('d460',
#    array([[ 423.86914, 1176.957  ],
#           [ 539.0957 , 1176.957  ],
#           [ 539.0957 , 1220.167  ],
#           [ 423.86914, 1220.167  ]], dtype=float32)),
#   ('da75a',
#    array([[ 609.0547, 1228.3975],
#           [ 757.2031, 1228.3975],
#           [ 757.2031, 1271.6074],
#           [ 609.0547, 1271.6074]], dtype=float32)),
#   ('d462',
#    array([[ 351.85254, 1259.2617 ],
#           [ 467.0791 , 1259.2617 ],
#           [ 467.0791 , 1302.4717 ],
#           [ 351.85254, 1302.4717 ]], dtype=float32)),
#   ('d461',
#    array([[1298.3564, 1261.3193],
#           [1409.4678, 1261.3193],
#           [1409.4678, 1302.4717],
#           [1298.3564, 1302.4717]], dtype=float32)),
#   ('d464',
#    array([[ 349.79492, 1407.4102 ],
#           [ 469.13672, 1407.4102 ],
#           [ 469.13672, 1452.6777 ],
#           [ 349.79492, 1452.6777 ]], dtype=float32)),
#   ('d475',
#    array([[ 804.5283, 1430.044 ],
#           [ 921.8125, 1430.044 ],
#           [ 921.8125, 1473.2539],
#           [ 804.5283, 1473.2539]], dtype=float32)),
#   ('d463',
#    array([[1181.0723, 1473.2539],
#           [1298.3564, 1473.2539],
#           [1298.3564, 1516.4639],
#           [1181.0723, 1516.4639]], dtype=float32)),
#   ('d471',
#    array([[ 504.1162 , 1500.0029 ],
#           [ 615.22754, 1500.0029 ],
#           [ 615.22754, 1543.2129 ],
#           [ 504.1162 , 1543.2129 ]], dtype=float32)),
#   ('d466',
#    array([[ 205.76172, 1569.9619 ],
#           [ 325.10352, 1569.9619 ],
#           [ 325.10352, 1615.2295 ],
#           [ 205.76172, 1615.2295 ]], dtype=float32)),
#   ('d468',
#    array([[ 269.54785, 1646.0938 ],
#           [ 384.7744 , 1646.0938 ],
#           [ 384.7744 , 1689.3037 ],
#           [ 269.54785, 1689.3037 ]], dtype=float32)),
#   ('da70',
#    array([[ 351.85254, 1726.3408 ],
#           [ 467.0791 , 1726.3408 ],
#           [ 467.0791 , 1769.5508 ],
#           [ 351.85254, 1769.5508 ]], dtype=float32)),
#   ('da72',
#    array([[ 423.86914, 1777.7812 ],
#           [ 539.0957 , 1777.7812 ],
#           [ 539.0957 , 1820.9912 ],
#           [ 423.86914, 1820.9912 ]], dtype=float32)),
#   ('d476',
#    array([[ 604.93945, 1777.7812 ],
#           [ 720.166  , 1777.7812 ],
#           [ 720.166  , 1820.9912 ],
#           [ 604.93945, 1820.9912 ]], dtype=float32)),
#   ('d474',
#    array([[ 504.5761, 1864.3489],
#           [ 622.2025, 1868.1433],
#           [ 620.8208, 1910.9768],
#           [ 503.1944, 1907.1824]], dtype=float32))]]
